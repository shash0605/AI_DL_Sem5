# %%
# !pip install --upgrade pip
# !pip install ultralytics -q
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\ayush\appdata\roaming\python\python313\site-packages (25.1.1)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Python313\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8n.pt')

# %%
choice = input("Enter 'img' to upload an image or 'cam' to use live camera: ").strip().lower()

if choice == 'img':
    img_path = input("Enter image file path: ").strip()
    results = model.predict(source=img_path, conf=0.5)

    for r in results:
        annotated_img = r.plot()
        plt.figure(figsize=(8, 8))
        plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()
        
        
elif choice == 'cam':
    cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO detection
    results = model(frame)
    annotated_frame = results[0].plot()

    # Show the frame
    cv2.imshow("YOLO Live Camera", annotated_frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 506.1ms
# Speed: 13.0ms preprocess, 506.1ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.7ms
# Speed: 1.7ms preprocess, 112.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.7ms
# Speed: 1.6ms preprocess, 87.7ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.7ms
# Speed: 1.9ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.8ms
# Speed: 2.8ms preprocess, 93.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.7ms
# Speed: 1.7ms preprocess, 106.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.6ms
# Speed: 2.0ms preprocess, 136.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Speed: 2.2ms preprocess, 118.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.4ms
# Speed: 2.6ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.3ms
# Speed: 1.5ms preprocess, 115.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 101.0ms
# Speed: 2.3ms preprocess, 101.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 89.3ms
# Speed: 3.5ms preprocess, 89.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 130.7ms
# Speed: 1.7ms preprocess, 130.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 refrigerator, 120.7ms
# Speed: 2.1ms preprocess, 120.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 122.7ms
# Speed: 1.7ms preprocess, 122.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 89.9ms
# Speed: 1.4ms preprocess, 89.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 150.4ms
# Speed: 1.5ms preprocess, 150.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 117.0ms
# Speed: 3.8ms preprocess, 117.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 131.9ms
# Speed: 1.4ms preprocess, 131.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 84.7ms
# Speed: 1.8ms preprocess, 84.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 113.6ms
# Speed: 2.2ms preprocess, 113.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 141.1ms
# Speed: 1.6ms preprocess, 141.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 refrigerator, 149.0ms
# Speed: 1.6ms preprocess, 149.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 128.0ms
# Speed: 2.3ms preprocess, 128.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 76.6ms
# Speed: 2.6ms preprocess, 76.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 132.9ms
# Speed: 1.6ms preprocess, 132.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 131.9ms
# Speed: 2.3ms preprocess, 131.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.8ms
# Speed: 2.7ms preprocess, 123.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.8ms
# Speed: 1.5ms preprocess, 98.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 84.8ms
# Speed: 1.6ms preprocess, 84.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 122.0ms
# Speed: 4.6ms preprocess, 122.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 132.0ms
# Speed: 1.7ms preprocess, 132.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 117.2ms
# Speed: 2.9ms preprocess, 117.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 81.6ms
# Speed: 2.7ms preprocess, 81.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 127.3ms
# Speed: 1.6ms preprocess, 127.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 95.0ms
# Speed: 1.6ms preprocess, 95.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 83.5ms
# Speed: 1.8ms preprocess, 83.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 fork, 111.2ms
# Speed: 2.2ms preprocess, 111.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 97.4ms
# Speed: 1.8ms preprocess, 97.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 100.0ms
# Speed: 2.2ms preprocess, 100.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.6ms
# Speed: 2.1ms preprocess, 106.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 120.5ms
# Speed: 1.9ms preprocess, 120.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 102.7ms
# Speed: 1.1ms preprocess, 102.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.3ms
# Speed: 4.2ms preprocess, 101.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.5ms
# Speed: 2.7ms preprocess, 124.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.8ms
# Speed: 1.8ms preprocess, 138.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.0ms
# Speed: 1.9ms preprocess, 112.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.4ms
# Speed: 2.5ms preprocess, 90.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.9ms
# Speed: 2.4ms preprocess, 121.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.7ms
# Speed: 1.9ms preprocess, 123.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.5ms
# Speed: 1.6ms preprocess, 81.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 105.7ms
# Speed: 3.3ms preprocess, 105.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.5ms
# Speed: 2.4ms preprocess, 99.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.2ms
# Speed: 1.5ms preprocess, 95.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.2ms
# Speed: 1.7ms preprocess, 90.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
